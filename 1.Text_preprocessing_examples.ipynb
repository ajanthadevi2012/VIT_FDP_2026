# %% [markdown]
# Word Tokenisation
# ============

# %%
text = "The quick brown fox jumped over the lazy dog"

tokens = text.split()
print(tokens)
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumped', 'over', 'the', 'lazy', 'dog']

# %%
text = "How about currencies (like £100,000.00)"

tokens = text.split()
print(tokens)
# Out:
# ['How', 'about', 'currencies', '(like', '£100,000.00)']

# %%
text = "The quick brown fox, and an Oxford comma"

tokens = text.split()
print(tokens)
# Out:
# ['The', 'quick', 'brown', 'fox,', 'and', 'an', 'Oxford', 'comma']

# %%
text = "The quick brown fox , and an Oxford comma"

tokens = text.split()
print(tokens)
# Out:
# ['The', 'quick', 'brown', 'fox', ',', 'and', 'an', 'Oxford', 'comma']

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\ajant\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\ajant\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\ajant\anaconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ajant\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\ajant\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\ajant\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\ajant\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

text = "The quick brown fox, and an Oxford comma"

tokens = word_tokenize(text)
print(tokens)
# Out:
# ['The', 'quick', 'brown', 'fox', ',', 'and', 'an', 'Oxford', 'comma']

# %%
from nltk.tokenize import word_tokenize

text = "Tweet about #NLProc @VIT_Vellore :)"

tokens = word_tokenize(text)
print(tokens)
# Out:
# ['Tweet', 'about', '#', 'NLProc', '@', 'VIT_Vellore', ':', ')']

# %%
from nltk.tokenize import TweetTokenizer

text = "Tweet about #NLProc @VIT_Vellore :)"

tokenizer = TweetTokenizer()
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['Tweet', 'about', '#NLProc', '@VIT_Vellore', ':)']

# %%
from nltk.tokenize import TweetTokenizer
text = "Tweet about #NLProc @VIT_Vellore :)"

tokenizer = TweetTokenizer(strip_handles= True)
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['Tweet', 'about', '#NLProc', ':)']

# %%
from nltk.tokenize import word_tokenize
text = "How about currencies (like £100,000.00) and dates (like 19th September)"

tokens = word_tokenize(text)
print(tokens)
# Out:
# ['How', 'about', 'currencies', '(', 'like', '£100,000.00', ')', 'and', 'dates', '(', 'like', '19th', 'September', ')']

# %% [markdown]
# Stemming
# =====

# %%
from nltk.stem import PorterStemmer

s = PorterStemmer()
print(s.stem('Having'))
print(s.stem('Have'))
print(s.stem('Had'))
# Out:
# have
# have
# had

# %%
print(s.stem('Fishing'))
print(s.stem('Fish'))
print(s.stem('Fisher'))
print(s.stem('Fishes'))
print(s.stem('Fished'))
# Out:
# fish
# fish
# fisher
# fish
# fish

# %% [markdown]
# Lemmatisation
# =====
#
# Lemmatisation is similar to stemming, as it produces a normalised version of the input word.
#
# The output is a lemma, i.e. a proper word (different from stemming)
#
# The input word is lemmatised according to its Part-of-Speech (POS) tag, i.e. verb, noun, etc.

# %%
# You'll need the "wordnet" package from NLTK data
# python -m nltk.downloader wordnet
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer

s = WordNetLemmatizer()
print(s.lemmatize('having', pos='v'))
print(s.lemmatize('have', pos='v'))
print(s.lemmatize('had', pos='v'))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ajant\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# have
# have
# have

# %%
print(s.lemmatize('fishing', pos='v'))
print(s.lemmatize('fish', pos='v'))
print(s.lemmatize('fisher', pos='n'))
print(s.lemmatize('fishes', pos='v'))
print(s.lemmatize('fished', pos='v'))
# Out:
# fish
# fish
# fisher
# fish
# fish

# %%
print(s.lemmatize('am', pos='v'))
print(s.lemmatize('is', pos='v'))
print(s.lemmatize('was', pos='v'))
# Out:
# be
# be
# be
